# %% [markdown]
# ## 1

# %%
import pandas as pd

# %%
df =pd.read_csv('winequality-red.csv')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Fixed acidity ,volatile acidity and till alcohol will decide quality of the wine .

# %% [markdown]
# ## 2

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# There is no null in the data as of now in this table.
# But we can use different imputation techniques,like mean ,mode and median ,depends on the data type and skewness of the data

# %% [markdown]
# ## 3

# %%
df =pd.read_csv('stud.csv')

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df['average']= (df['math_score']+df['reading_score']+df['writing_score'])/3

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
sns.histplot(data=df,x='average',hue='gender',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
sns.histplot(data=df,x='average',hue='race_ethnicity',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
sns.histplot(data=df,x='average',hue='parental_level_of_education',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
sns.histplot(data=df,x='average',hue='lunch',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_106/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >

# %% [markdown]
# ## 4

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'average'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one_encoded = OneHotEncoder(sparse=False)

# %%
one_coded = one_encoded.fit_transform(df[['gender']])
one_coded = pd.DataFrame(one_coded,columns=['female','male'])
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
encoded = pd.concat([one_coded,df],axis=1)

# %%
encoded
# Out:
#      female  male  gender race_ethnicity parental_level_of_education  \
# 0       1.0   0.0  female        group B           bachelor's degree
# 1       1.0   0.0  female        group C                some college
# 2       1.0   0.0  female        group B             master's degree
# 3       0.0   1.0    male        group A          associate's degree
# 4       0.0   1.0    male        group C                some college
# ..      ...   ...     ...            ...                         ...
# 995     1.0   0.0  female        group E             master's degree
# 996     0.0   1.0    male        group C                 high school
# 997     1.0   0.0  female        group C                 high school
# 998     1.0   0.0  female        group D                some college
# 999     1.0   0.0  female        group D                some college
#
#             lunch test_preparation_course  math_score  reading_score  \
# ...

# %% [markdown]
# ## 5

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

##Grid 2x5 plots 
plt.subplots(2,5,figsize=(25,6))

plt.subplot(251)
sns.histplot(data=df,x='fixed acidity',kde=True)

plt.subplot(252)
sns.histplot(data=df,x='volatile acidity',kde=True)

## position 3rd
plt.subplot(253)
sns.histplot(data=df,x='citric acid',kde=True)

plt.subplot(254)
sns.histplot(data=df,x='residual sugar',kde=True)

plt.subplot(255)
sns.histplot(data=df,x='chlorides',kde=True)

plt.subplot(256)
sns.histplot(data=df,x='total sulfur dioxide',kde=True)

plt.subplot(257)
sns.histplot(data=df,x='density',kde=True)

plt.subplot(258)
sns.histplot(data=df,x='pH',kde=True)

plt.subplot(259)
sns.histplot(data=df,x='sulphates',kde=True)

plt.subplot(2,5,10)
sns.histplot(data=df,x='alcohol',kde=True)

plt.show()

# %% [markdown]
# Non - noramiltiy = [ 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide',
#        'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# Through normalization we can convert these features in normalised form

# %%
## We can use power transformer to standardise the data 
from sklearn.preprocessing import PowerTransformer

# %%
# Initialize PowerTransformer
power_transformer = PowerTransformer(method='box-cox', standardize=True)

# %%
# Fit and transform the skewed data
transformed_data = power_transformer.fit_transform(df[['total sulfur dioxide']])

# %%
df['total sulfur dioxide'] = pd.DataFrame(transformed_data)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70    -0.123215             1.9      0.076
# 1            7.8              0.88     0.852473             2.6      0.098
# 2            7.8              0.76     0.538557             2.3      0.092
# 3           11.2              0.28     0.691456             1.9      0.075
# 4            7.4              0.70    -0.123215             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0             -0.123215   0.9978  3.51       0.56
# 1                 25.0              0.852473   0.9968  3.20       0.68
# 2                 15.0              0.538557   0.9970  3.26       0.65
# 3                 17.0              0.691456   0.9980  3.16       0.58
# 4                 11.0             -0.123215   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.histplot(data=df,x='total sulfur dioxide',kde=True)
# Out:
# <AxesSubplot: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700    -0.123215             1.9      0.076
# 1               7.8             0.880     0.852473             2.6      0.098
# 2               7.8             0.760     0.538557             2.3      0.092
# 3              11.2             0.280     0.691456             1.9      0.075
# 4               7.4             0.700    -0.123215             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600     0.243686             2.0      0.090
# 1595            5.9             0.550     0.455950             2.2      0.062
# 1596            6.3             0.510     0.107497             2.3      0.076
# 1597            5.9             0.645     0.243686             2.0      0.075
# 1598            6.0             0.310     0.177131             3.6      0.067
#
# ...

# %% [markdown]
# ## 7

# %%
## PCA 

import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming 'df' is your DataFrame with the features you provided
# Replace 'target_column' with the column containing the target variable if applicable
target_column = 'quality'
X = df.drop(columns=[target_column])  # Exclude the target variable from the features

# Standardize the features (important for PCA)
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_standardized)

# Determine the number of components to keep
explained_variance_ratio_cumsum = pca.explained_variance_ratio_.cumsum()
num_components_to_keep = (explained_variance_ratio_cumsum <= 0.95).sum()

# Apply PCA with the chosen number of components
pca_final = PCA(n_components=num_components_to_keep)
X_pca_final = pca_final.fit_transform(X_standardized)

# Create a DataFrame with the principal components
columns_pca = [f'PC{i+1}' for i in range(num_components_to_keep)]
df_pca = pd.DataFrame(data=X_pca_final, columns=columns_pca)

# Concatenate the principal components DataFrame with the target variable
df_result = pd.concat([df[target_column], df_pca], axis=1)

# Display the result
print(df_result.head())
# Out:
#    quality       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0        5 -0.301222 -0.754483  1.771655  0.298875 -0.035250 -0.915962
# 1        5  1.680091 -0.475052  1.081703  0.620744  0.075670  1.072104
# 2        5  0.779052 -0.264872  1.058593  0.519500 -0.119287  0.478256
# 3        6  1.072208  1.510716 -0.416016 -0.936100 -1.650885 -0.091735
# 4        5 -0.301222 -0.754483  1.771655  0.298875 -0.035250 -0.915962
#
#         PC7
# 0 -0.327841
# 1 -0.767363
# 2 -0.494128
# 3  0.313763
# 4 -0.327841

# %%
range(num_components_to_keep)
# Out:
# range(0, 7)

# %%
num_components_to_keep
# Out:
# 7

# %%
explained_variance_ratio_cumsum
# Out:
# array([0.25581889, 0.48594796, 0.61765728, 0.72654116, 0.81677083,
#        0.87565247, 0.92943058, 0.96394453, 0.99454147, 1.        ,
#        1.        ])

# %%
df1= pd.read_csv('winequality-red.csv')
plt.figure(figsize=(25,6))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df2 = pd.read_csv('stud.csv')

# %%
plt.figure(figsize=(25,6))
sns.heatmap(df2.corr(),annot=True)
# Out:
# /tmp/ipykernel_106/3867734457.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(),annot=True)
# <AxesSubplot: >
